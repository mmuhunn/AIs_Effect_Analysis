# %%
import sys
sys.executable
# Out:
# 'C:\\Users\\Daehun\\AppData\\Local\\Programs\\Python\\Python312\\python.exe'

# %%
# !{sys.executable} -m pip install impyla thrift
# Out:
# ...
#   Using cached impyla-0.22.0-py2.py3-none-any.whl.metadata (7.7 kB)
# ...
#   Using cached thrift-0.22.0.tar.gz (62 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Using cached thrift-0.16.0.tar.gz (59 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Using cached thrift_sasl-0.4.3-py2.py3-none-any.whl.metadata (1.2 kB)
# ...
#   Using cached pure-sasl-0.6.2.tar.gz (11 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Using cached impyla-0.22.0-py2.py3-none-any.whl (310 kB)
# Using cached thrift_sasl-0.4.3-py2.py3-none-any.whl (8.3 kB)
# ...
#   Created wheel for thrift: filename=thrift-0.16.0-py3-none-any.whl size=194501 sha256=63ba37023ea425ac9992505b19546d90707b6cdc25f98d9f8930e93a9fab74d1
# ...

# %%
import impala
impala.__version__
# Out:
# 'v0.22.0'

# %%
# !{sys.executable} -m pip uninstall -y impyla
# !{sys.executable} -m pip install impyla==0.16.2
# Out:
# Found existing installation: impyla 0.22.0
# Uninstalling impyla-0.22.0:
#   Successfully uninstalled impyla-0.22.0
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'error'
#   error: subprocess-exited-with-error
#
#   python setup.py egg_info did not run successfully.
#   exit code: 1
#
#   [18 lines of output]
#   C:\Users\Daehun\AppData\Local\Temp\pip-install-2rp51b9s\impyla_b0e060e77a844785b733ced0d5c4db31\versioneer.py:418: SyntaxWarning: invalid escape sequence '\s'
#     LONG_VERSION_PY['git'] = '''
#   Traceback (most recent call last):
#     File "<string>", line 2, in <module>
#     File "<pip-setuptools-caller>", line 34, in <module>
#     File "C:\Users\Daehun\AppData\Local\Temp\pip-install-2rp51b9s\impyla_b0e060e77a844785b733ced0d5c4db31\setup.py", line 31, in <module>
#       version=versioneer.get_version(),
#               ^^^^^^^^^^^^^^^^^^^^^^^^
# ...

# %%
import impala
impala.__version__
# Out:
# 'v0.22.0'

# %%
import subprocess
import pandas as pd
import io

cmd = 'impala-shell -B -q "SELECT title, views FROM spark_results_2023 LIMIT 10"'
out = subprocess.check_output(cmd, shell=True)

df = pd.read_csv(io.StringIO(out.decode()), sep='\t', header=None, names=['title','views'])
df
# Out:
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Cell In[13], line 6
#       3 import io
#       5 cmd = 'impala-shell -B -q "SELECT title, views FROM spark_results_2023 LIMIT 10"'
# ----> 6 out = subprocess.check_output(cmd, shell=True)
#       8 df = pd.read_csv(io.StringIO(out.decode()), sep='\t', header=None, names=['title','views'])
#       9 df
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\subprocess.py:466, in check_output(timeout, *popenargs, **kwargs)
#     463         empty = b''
#     464     kwargs['input'] = empty
# --> 466 return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
#     467            **kwargs).stdout
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\subprocess.py:571, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     569     retcode = process.poll()
#     570     if check and retcode:
# ...
